# %% [markdown]
# # Cancer Patient Classification With CNN

# %% [markdown]
# The "Cancer Patient Classification with Convolutional Neural Networks (CNN) Project" is a research endeavor aimed at revolutionizing cancer diagnosis and treatment through the application of cutting-edge deep learning techniques. Leveraging the power of CNNs, this project seeks to develop a robust and accurate model capable of classifying cancer patients based on medical imaging data.

# %% [markdown]
# # Importing Libraries

# %% [markdown]
# These are just a few examples of popular Python libraries. You can import any other library using the same import statement followed by the library name or alias:
#
# NumPy: for numerical operations and array manipulation
#
# Pandas: for data manipulation and analysis
#
# Matplotlib: for creating visualizations
#
# Scikit-learn: for machine learning algorithms.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %%
dataframe = pd.read_csv('Cancer_Data.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Before building the CNN model, it is essential to perform exploratory analysis on the dataset to gain insights and understand the underlying patterns and characteristics of the data

# %%
dataframe.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
dataframe.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [5 rows x 33 columns]

# %%
dataframe.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
dataframe = dataframe.drop(['Unnamed: 32', 'id'], axis = 1)

# %%
dataframe.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# # Encoding

# %% [markdown]
# Encoding is the process of converting data or information from one format or representation to another, typically to make it more suitable for a specific purpose, such as storage, transmission, or processing.

# %% [markdown]
# Label Encoding is a data preprocessing technique that converts categorical variables into numerical values by assigning a unique integer to each category. It facilitates the use of machine learning algorithms with textual data but may introduce an implicit order between labels, which should be considered when dealing with non-ordinal variables.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
dataframe['diagnosis'] = encoder.fit_transform(dataframe['diagnosis'])

# %%
dataframe.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int32
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int32(1)
# memory usage: 135.7 KB

# %% [markdown]
# # Checking Null Values

# %%
dataframe.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# # Distribution Of Cancer Diagnosis

# %%
dataframe['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
dataframe['diagnosis'].value_counts().plot(kind = 'bar', 
                                           title = 'Distribution Of Cnacer Diagnosis', 
                                           figsize = (8, 3), 
                                           cmap = 'ocean')
# Out:
# <AxesSubplot:title={'center':'Distribution Of Cnacer Diagnosis'}>

# %% [markdown]
# # Statical Info

# %% [markdown]
# Statistical information refers to numerical data or metrics that describe various aspects of a dataset or population. These statistics provide quantitative measures of central tendency, dispersion, relationships, and other properties of the data.

# %%
dataframe.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count     569.000000  ...    569.000000     569.000000       569.000000
# mean        0.181162  ...     16.269190      25.677223       107.261213
# std         0.027414  ...      4.833242       6.146258        33.602542
# min         0.106000  ...      7.930000      12.020000        50.410000
# 25%         0.161900  ...     13.010000      21.080000        84.110000
# 50%         0.179200  ...     14.970000      25.410000        97.660000
# 75%         0.195700  ...     18.790000      29.720000       125.400000
# max         0.304000  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count   569.000000        569.000000         569.000000       569.000000
# mean    880.583128          0.132369           0.254265         0.272188
# std     569.356993          0.022832           0.157336         0.208624
# min     185.200000          0.071170           0.027290         0.000000
# 25%     515.300000          0.116600           0.147200         0.114500
# 50%     686.500000          0.131300           0.211900         0.226700
# 75%    1084.000000          0.146000           0.339100         0.382900
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 31 columns]

# %% [markdown]
# # Correlation Matrix

# %% [markdown]
# A correlation matrix is a table that shows the pairwise correlations between variables in a dataset. Each cell in the table represents the correlation between two variables, and the strength and direction of the correlation is indicated by the color and magnitude of the cell.
#
# Correlation matrices are commonly used in data analysis to identify relationships between variables and to help understand the structure of the data. The values in the correlation matrix range from -1 to 1, with -1 indicating a perfect negative correlation, 1 indicating a perfect positive correlation, and 0 indicating no correlation.

# %%
corr_matrix = dataframe.corr()

# %%
corr_matrix
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.730029      0.415185        0.742636
# radius_mean               0.730029     1.000000      0.323782        0.997855
# texture_mean              0.415185     0.323782      1.000000        0.329533
# perimeter_mean            0.742636     0.997855      0.329533        1.000000
# area_mean                 0.708984     0.987357      0.321086        0.986507
# smoothness_mean           0.358560     0.170581     -0.023389        0.207278
# compactness_mean          0.596534     0.506124      0.236702        0.556936
# concavity_mean            0.696360     0.676764      0.302418        0.716136
# concave points_mean       0.776614     0.822529      0.293464        0.850977
# symmetry_mean             0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437       -0.261477
# radius_se                 0.567134     0.679090      0.275869        0.691765
# texture_se               -0.008303    -0.097317      0.386358       -0.086761
# perimeter_se              0.556141     0.674172      0.281673        0.693135
# area_se                   0.548236     0.735864      0.259845        0.744983
# smoothness_se            -0.067016    -0.222600      0.006614       -0.202694
# compactness_se            0.292999     0.206000      0.191975        0.250744
# concavity_se              0.253730     0.194204      0.143293        0.228082
# concave points_se         0.408042     0.376169      0.163851        0.407217
# symmetry_se              -0.006522    -0.104321      0.009127       -0.081629
# fractal_dimension_se      0.077972    -0.042641      0.054458       -0.005523
# radius_worst              0.776454     0.969539      0.352573        0.969476
# texture_worst             0.456903     0.297008      0.912045        0.303038
# perimeter_worst           0.782914     0.965137      0.358040        0.970387
# area_worst                0.733825     0.941082      0.343546        0.941550
# smoothness_worst          0.421465     0.119616      0.077503        0.150549
# compactness_worst         0.590998     0.413463      0.277830        0.455774
# concavity_worst           0.659610     0.526911      0.301025        0.563879
# concave points_worst      0.793566     0.744214      0.295316        0.771241
# symmetry_worst            0.416294     0.163953      0.105008        0.189115
# fractal_dimension_worst   0.323872     0.007066      0.119205        0.051019
#
#                          area_mean  smoothness_mean  compactness_mean  \
# diagnosis                 0.708984         0.358560          0.596534
# radius_mean               0.987357         0.170581          0.506124
# texture_mean              0.321086        -0.023389          0.236702
# perimeter_mean            0.986507         0.207278          0.556936
# area_mean                 1.000000         0.177028          0.498502
# smoothness_mean           0.177028         1.000000          0.659123
# compactness_mean          0.498502         0.659123          1.000000
# concavity_mean            0.685983         0.521984          0.883121
# concave points_mean       0.823269         0.553695          0.831135
# symmetry_mean             0.151293         0.557775          0.602641
# fractal_dimension_mean   -0.283110         0.584792          0.565369
# radius_se                 0.732562         0.301467          0.497473
# texture_se               -0.066280         0.068406          0.046205
# perimeter_se              0.726628         0.296092          0.548905
# area_se                   0.800086         0.246552          0.455653
# smoothness_se            -0.166777         0.332375          0.135299
# compactness_se            0.212583         0.318943          0.738722
# concavity_se              0.207660         0.248396          0.570517
# concave points_se         0.372320         0.380676          0.642262
# symmetry_se              -0.072497         0.200774          0.229977
# fractal_dimension_se     -0.019887         0.283607          0.507318
# radius_worst              0.962746         0.213120          0.535315
# texture_worst             0.287489         0.036072          0.248133
# perimeter_worst           0.959120         0.238853          0.590210
# area_worst                0.959213         0.206718          0.509604
# smoothness_worst          0.123523         0.805324          0.565541
# compactness_worst         0.390410         0.472468          0.865809
# concavity_worst           0.512606         0.434926          0.816275
# concave points_worst      0.722017         0.503053          0.815573
# symmetry_worst            0.143570         0.394309          0.510223
# fractal_dimension_worst   0.003738         0.499316          0.687382
#
#                          concavity_mean  concave points_mean  symmetry_mean  \
# diagnosis                      0.696360             0.776614       0.330499
# radius_mean                    0.676764             0.822529       0.147741
# texture_mean                   0.302418             0.293464       0.071401
# perimeter_mean                 0.716136             0.850977       0.183027
# area_mean                      0.685983             0.823269       0.151293
# smoothness_mean                0.521984             0.553695       0.557775
# compactness_mean               0.883121             0.831135       0.602641
# concavity_mean                 1.000000             0.921391       0.500667
# concave points_mean            0.921391             1.000000       0.462497
# symmetry_mean                  0.500667             0.462497       1.000000
# fractal_dimension_mean         0.336783             0.166917       0.479921
# radius_se                      0.631925             0.698050       0.303379
# texture_se                     0.076218             0.021480       0.128053
# perimeter_se                   0.660391             0.710650       0.313893
# area_se                        0.617427             0.690299       0.223970
# smoothness_se                  0.098564             0.027653       0.187321
# compactness_se                 0.670279             0.490424       0.421659
# concavity_se                   0.691270             0.439167       0.342627
# concave points_se              0.683260             0.615634       0.393298
# symmetry_se                    0.178009             0.095351       0.449137
# fractal_dimension_se           0.449301             0.257584       0.331786
# radius_worst                   0.688236             0.830318       0.185728
# texture_worst                  0.299879             0.292752       0.090651
# perimeter_worst                0.729565             0.855923       0.219169
# area_worst                     0.675987             0.809630       0.177193
# smoothness_worst               0.448822             0.452753       0.426675
# compactness_worst              0.754968             0.667454       0.473200
# concavity_worst                0.884103             0.752399       0.433721
# concave points_worst           0.861323             0.910155       0.430297
# symmetry_worst                 0.409464             0.375744       0.699826
# fractal_dimension_worst        0.514930             0.368661       0.438413
#
#                          ...  radius_worst  texture_worst  perimeter_worst  \
# diagnosis                ...      0.776454       0.456903         0.782914
# radius_mean              ...      0.969539       0.297008         0.965137
# texture_mean             ...      0.352573       0.912045         0.358040
# perimeter_mean           ...      0.969476       0.303038         0.970387
# area_mean                ...      0.962746       0.287489         0.959120
# smoothness_mean          ...      0.213120       0.036072         0.238853
# compactness_mean         ...      0.535315       0.248133         0.590210
# concavity_mean           ...      0.688236       0.299879         0.729565
# concave points_mean      ...      0.830318       0.292752         0.855923
# symmetry_mean            ...      0.185728       0.090651         0.219169
# fractal_dimension_mean   ...     -0.253691      -0.051269        -0.205151
# radius_se                ...      0.715065       0.194799         0.719684
# texture_se               ...     -0.111690       0.409003        -0.102242
# perimeter_se             ...      0.697201       0.200371         0.721031
# area_se                  ...      0.757373       0.196497         0.761213
# smoothness_se            ...     -0.230691      -0.074743        -0.217304
# compactness_se           ...      0.204607       0.143003         0.260516
# concavity_se             ...      0.186904       0.100241         0.226680
# concave points_se        ...      0.358127       0.086741         0.394999
# symmetry_se              ...     -0.128121      -0.077473        -0.103753
# fractal_dimension_se     ...     -0.037488      -0.003195        -0.001000
# radius_worst             ...      1.000000       0.359921         0.993708
# texture_worst            ...      0.359921       1.000000         0.365098
# perimeter_worst          ...      0.993708       0.365098         1.000000
# area_worst               ...      0.984015       0.345842         0.977578
# smoothness_worst         ...      0.216574       0.225429         0.236775
# compactness_worst        ...      0.475820       0.360832         0.529408
# concavity_worst          ...      0.573975       0.368366         0.618344
# concave points_worst     ...      0.787424       0.359755         0.816322
# symmetry_worst           ...      0.243529       0.233027         0.269493
# fractal_dimension_worst  ...      0.093492       0.219122         0.138957
#
#                          area_worst  smoothness_worst  compactness_worst  \
# diagnosis                  0.733825          0.421465           0.590998
# radius_mean                0.941082          0.119616           0.413463
# texture_mean               0.343546          0.077503           0.277830
# perimeter_mean             0.941550          0.150549           0.455774
# area_mean                  0.959213          0.123523           0.390410
# smoothness_mean            0.206718          0.805324           0.472468
# compactness_mean           0.509604          0.565541           0.865809
# concavity_mean             0.675987          0.448822           0.754968
# concave points_mean        0.809630          0.452753           0.667454
# symmetry_mean              0.177193          0.426675           0.473200
# fractal_dimension_mean    -0.231854          0.504942           0.458798
# radius_se                  0.751548          0.141919           0.287103
# texture_se                -0.083195         -0.073658          -0.092439
# perimeter_se               0.730713          0.130054           0.341919
# area_se                    0.811408          0.125389           0.283257
# smoothness_se             -0.182195          0.314457          -0.055558
# compactness_se             0.199371          0.227394           0.678780
# concavity_se               0.188353          0.168481           0.484858
# concave points_se          0.342271          0.215351           0.452888
# symmetry_se               -0.110343         -0.012662           0.060255
# fractal_dimension_se      -0.022736          0.170568           0.390159
# radius_worst               0.984015          0.216574           0.475820
# texture_worst              0.345842          0.225429           0.360832
# perimeter_worst            0.977578          0.236775           0.529408
# area_worst                 1.000000          0.209145           0.438296
# smoothness_worst           0.209145          1.000000           0.568187
# compactness_worst          0.438296          0.568187           1.000000
# concavity_worst            0.543331          0.518523           0.892261
# concave points_worst       0.747419          0.547691           0.801080
# symmetry_worst             0.209146          0.493838           0.614441
# fractal_dimension_worst    0.079647          0.617624           0.810455
#
#                          concavity_worst  concave points_worst  \
# diagnosis                       0.659610              0.793566
# radius_mean                     0.526911              0.744214
# texture_mean                    0.301025              0.295316
# perimeter_mean                  0.563879              0.771241
# area_mean                       0.512606              0.722017
# smoothness_mean                 0.434926              0.503053
# compactness_mean                0.816275              0.815573
# concavity_mean                  0.884103              0.861323
# concave points_mean             0.752399              0.910155
# symmetry_mean                   0.433721              0.430297
# fractal_dimension_mean          0.346234              0.175325
# radius_se                       0.380585              0.531062
# texture_se                     -0.068956             -0.119638
# perimeter_se                    0.418899              0.554897
# area_se                         0.385100              0.538166
# smoothness_se                  -0.058298             -0.102007
# compactness_se                  0.639147              0.483208
# concavity_se                    0.662564              0.440472
# concave points_se               0.549592              0.602450
# symmetry_se                     0.037119             -0.030413
# fractal_dimension_se            0.379975              0.215204
# radius_worst                    0.573975              0.787424
# texture_worst                   0.368366              0.359755
# perimeter_worst                 0.618344              0.816322
# area_worst                      0.543331              0.747419
# smoothness_worst                0.518523              0.547691
# compactness_worst               0.892261              0.801080
# concavity_worst                 1.000000              0.855434
# concave points_worst            0.855434              1.000000
# symmetry_worst                  0.532520              0.502528
# fractal_dimension_worst         0.686511              0.511114
#
#                          symmetry_worst  fractal_dimension_worst
# diagnosis                      0.416294                 0.323872
# radius_mean                    0.163953                 0.007066
# texture_mean                   0.105008                 0.119205
# perimeter_mean                 0.189115                 0.051019
# area_mean                      0.143570                 0.003738
# smoothness_mean                0.394309                 0.499316
# compactness_mean               0.510223                 0.687382
# concavity_mean                 0.409464                 0.514930
# concave points_mean            0.375744                 0.368661
# symmetry_mean                  0.699826                 0.438413
# fractal_dimension_mean         0.334019                 0.767297
# radius_se                      0.094543                 0.049559
# texture_se                    -0.128215                -0.045655
# perimeter_se                   0.109930                 0.085433
# area_se                        0.074126                 0.017539
# smoothness_se                 -0.107342                 0.101480
# compactness_se                 0.277878                 0.590973
# concavity_se                   0.197788                 0.439329
# concave points_se              0.143116                 0.310655
# symmetry_se                    0.389402                 0.078079
# fractal_dimension_se           0.111094                 0.591328
# radius_worst                   0.243529                 0.093492
# texture_worst                  0.233027                 0.219122
# perimeter_worst                0.269493                 0.138957
# area_worst                     0.209146                 0.079647
# smoothness_worst               0.493838                 0.617624
# compactness_worst              0.614441                 0.810455
# concavity_worst                0.532520                 0.686511
# concave points_worst           0.502528                 0.511114
# symmetry_worst                 1.000000                 0.537848
# fractal_dimension_worst        0.537848                 1.000000
#
# [31 rows x 31 columns]

# %%
plt.figure(figsize = (18, 8))
sns.heatmap(
    corr_matrix, 
    annot = True, 
    cmap = 'coolwarm'
)
# Out:
# <AxesSubplot:>

# %%
dataframe.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
dataset = dataframe.drop('diagnosis', axis = 1)

# %%
dataset.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# # Correlation Of Cancer Diagnosis With Different Attibutes

# %%
dataset.corrwith(dataframe['diagnosis']).plot.bar(
    figsize = (12, 5), 
    title = 'Correlation Of Cance Diagnosis', 
    cmap = 'plasma'
)
# Out:
# <AxesSubplot:title={'center':'Correlation Of Cance Diagnosis'}>

# %%
dataframe.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# # Splitting Dataset

# %% [markdown]
# Dataset splitting is an important step in machine learning and data analysis. It involves dividing a dataset into two or more subsets to train and evaluate a model effectively. The most common type of dataset splitting is into training and testing subsets.
#
# Train-Test Split: This is the most basic type of split, where the dataset is divided into a training set and a testing set. The training set is used to train the machine learning model, while the testing set is used to evaluate its performance. The split is typically done using a fixed ratio, such as 80% for training and 20% for testing.

# %%
x = dataframe.drop('diagnosis', axis = 1)
y = dataframe['diagnosis']

# %%
x.shape, y.shape
# Out:
# ((569, 30), (569,))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, 
    y, 
    test_size = 0.2, 
    random_state = 42
)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((455, 30), (114, 30), (455,), (114,))

# %% [markdown]
# # Scaling

# %% [markdown]
# Scaling is a preprocessing step in machine learning that involves transforming the features or variables of your dataset to a consistent scale. It is important because many machine learning algorithms are sensitive to the scale of the input features. Scaling helps ensure that all features have a similar range and distribution, which can improve the performance and convergence of the model.
#
# StandardScaler is a popular scaling technique used in machine learning to standardize features by removing the mean and scaling to unit variance. It is available in the scikit-learn library, which provides a wide range of machine learning tools and preprocessing functions.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-1.44075296, -0.43531947, -1.36208497, ...,  0.9320124 ,
#          2.09724217,  1.88645014],
#        [ 1.97409619,  1.73302577,  2.09167167, ...,  2.6989469 ,
#          1.89116053,  2.49783848],
#        [-1.39998202, -1.24962228, -1.34520926, ..., -0.97023893,
#          0.59760192,  0.0578942 ],
#        ...,
#        [ 0.04880192, -0.55500086, -0.06512547, ..., -1.23903365,
#         -0.70863864, -1.27145475],
#        [-0.03896885,  0.10207345, -0.03137406, ...,  1.05001236,
#          0.43432185,  1.21336207],
#        [-0.54860557,  0.31327591, -0.60350155, ..., -0.61102866,
#         -0.3345212 , -0.84628745]])

# %%
x_test
# Out:
# array([[-0.46649743, -0.13728933, -0.44421138, ..., -0.19435087,
#          0.17275669,  0.20372995],
#        [ 1.36536344,  0.49866473,  1.30551088, ...,  0.99177862,
#         -0.561211  , -1.00838949],
#        [ 0.38006578,  0.06921974,  0.40410139, ...,  0.57035018,
#         -0.10783139, -0.20629287],
#        ...,
#        [-0.73547237, -0.99852603, -0.74138839, ..., -0.27741059,
#         -0.3820785 , -0.32408328],
#        [ 0.02898271,  2.0334026 ,  0.0274851 , ..., -0.49027026,
#         -1.60905688, -0.33137507],
#        [ 1.87216885,  2.80077153,  1.80354992, ...,  0.7925579 ,
#         -0.05868885, -0.09467243]])

# %% [markdown]
# # Reshaping

# %% [markdown]
# Reshaping to 1D refers to transforming multidimensional data, such as images, into a 1-dimensional vector representation. In the context of heart disease classification with CNNs, reshaping to 1D is typically performed on the input data to prepare it for feeding into the neural network model.

# %%
x_train.shape, x_test.shape
# Out:
# ((455, 30), (114, 30))

# %%
x_train = x_train.reshape(455, 30, 1)
x_test = x_test.reshape(114, 30, 1)

# %%
x_train.shape, x_test.shape
# Out:
# ((455, 30, 1), (114, 30, 1))

# %% [markdown]
# # Building Model

# %% [markdown]
# Creating a CNN model involves defining the architecture and structure of the neural network, specifying the layers, and configuring the parameters for training.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, BatchNormalization
from tensorflow.keras.layers import Flatten, Dropout, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()
model.add(Conv1D(filters = 32, kernel_size = 4,activation = 'relu', input_shape = (30, 1)))
model.add(MaxPooling1D(pool_size = 3))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv1D(filters = 64,kernel_size = 3, activation = 'relu'))
model.add(MaxPooling1D(pool_size = 3))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(64, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 27, 32)            160
#
#  max_pooling1d (MaxPooling1D  (None, 9, 32)            0
#  )
#
#  batch_normalization (BatchN  (None, 9, 32)            128
#  ormalization)
#
#  dropout (Dropout)           (None, 9, 32)             0
#
#  conv1d_1 (Conv1D)           (None, 7, 64)             6208
#
#  max_pooling1d_1 (MaxPooling  (None, 2, 64)            0
#  1D)
#
#  batch_normalization_1 (Batc  (None, 2, 64)            256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 2, 64)             0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 15,073
# Trainable params: 14,881
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# A model checkpoint, in the context of machine learning, refers to a saved copy of a trained model at a specific point during the training process. It includes the model's architecture, weights, and optimizer state.

# %%
checkpoint_path = "cancer_patient_classificaion"
checkpoint_callback = ModelCheckpoint(
    checkpoint_path, 
    save_weights_only = True, 
    monitor = 'val_accuracy',
    save_best_only = True
)

# %% [markdown]
# Early stopping is a technique used during the training of machine learning models to prevent overfitting and find the optimal point at which to stop training. It involves monitoring the performance of the model on a validation dataset and stopping the training process when the model's performance on the validation dataset starts to degrade.

# %%
early_stop = EarlyStopping(
    monitor = 'val_loss',
    patience = 5,
    restore_best_weights = True
)

# %% [markdown]
# ReduceLROnPlateau" is a learning rate scheduling technique commonly used in the training of deep learning models. It stands for "Reduce Learning Rate on Plateau" and is used to dynamically adjust the learning rate during training to optimize model performance.

# %%
reduce_lr = ReduceLROnPlateau(
    monitor = 'val_loss',
    factor = 0.2,
    patience = 3,
    min_le = 1e-10
)

# %%
from tensorflow.keras.callbacks import TensorBoard
import datetime

def create_tensorboard_callback(log_dir, experiment_name):
    log_dir = log_dir + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = TensorBoard(log_dir=log_dir)
    print(f"Saving TensorBoard log files to: {log_dir}")
    return tensorboard_callback

# %%
model.compile(optimizer = Adam(0.0001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# # Training Model

# %% [markdown]
# Training the model in deep learning involves the process of iteratively updating the model's parameters (weights and biases) based on the provided training data to minimize the loss function and improve the model's performance.

# %%
model.fit(
    x_train, y_train,
    validation_data = (x_test, y_test),
    epochs = 250, 
    callbacks = [early_stop, 
                 create_tensorboard_callback("training log",
                                             "cancer_patient_classification"),
                 checkpoint_callback, 
                 reduce_lr]
)
# Out:
# Saving TensorBoard log files to: training log/cancer_patient_classification/20230728-112935
# Epoch 1/250
# 15/15 [==============================] - 6s 89ms/step - loss: 0.9156 - accuracy: 0.5121 - val_loss: 0.6742 - val_accuracy: 0.6316 - lr: 1.0000e-04
# Epoch 2/250
# 15/15 [==============================] - 0s 30ms/step - loss: 0.7385 - accuracy: 0.6066 - val_loss: 0.6508 - val_accuracy: 0.7719 - lr: 1.0000e-04
# Epoch 3/250
# 15/15 [==============================] - 1s 41ms/step - loss: 0.5724 - accuracy: 0.7363 - val_loss: 0.6257 - val_accuracy: 0.7807 - lr: 1.0000e-04
# Epoch 4/250
# 15/15 [==============================] - 0s 21ms/step - loss: 0.5319 - accuracy: 0.7604 - val_loss: 0.6013 - val_accuracy: 0.7807 - lr: 1.0000e-04
# Epoch 5/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.4724 - accuracy: 0.7890 - val_loss: 0.5795 - val_accuracy: 0.7632 - lr: 1.0000e-04
# Epoch 6/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.4183 - accuracy: 0.8154 - val_loss: 0.5589 - val_accuracy: 0.7807 - lr: 1.0000e-04
# Epoch 7/250
# 15/15 [==============================] - 0s 28ms/step - loss: 0.4032 - accuracy: 0.8418 - val_loss: 0.5399 - val_accuracy: 0.7895 - lr: 1.0000e-04
# Epoch 8/250
# 15/15 [==============================] - 0s 29ms/step - loss: 0.4385 - accuracy: 0.8264 - val_loss: 0.5208 - val_accuracy: 0.7982 - lr: 1.0000e-04
# Epoch 9/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.3831 - accuracy: 0.8418 - val_loss: 0.5004 - val_accuracy: 0.7982 - lr: 1.0000e-04
# Epoch 10/250
# 15/15 [==============================] - 0s 21ms/step - loss: 0.3576 - accuracy: 0.8637 - val_loss: 0.4811 - val_accuracy: 0.7982 - lr: 1.0000e-04
# Epoch 11/250
# 15/15 [==============================] - 1s 33ms/step - loss: 0.3531 - accuracy: 0.8593 - val_loss: 0.4625 - val_accuracy: 0.8070 - lr: 1.0000e-04
# Epoch 12/250
# 15/15 [==============================] - 0s 28ms/step - loss: 0.3533 - accuracy: 0.8615 - val_loss: 0.4435 - val_accuracy: 0.8158 - lr: 1.0000e-04
# Epoch 13/250
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3110 - accuracy: 0.8791 - val_loss: 0.4233 - val_accuracy: 0.8158 - lr: 1.0000e-04
# Epoch 14/250
# 15/15 [==============================] - 0s 33ms/step - loss: 0.2994 - accuracy: 0.8835 - val_loss: 0.4041 - val_accuracy: 0.8246 - lr: 1.0000e-04
# Epoch 15/250
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3021 - accuracy: 0.8813 - val_loss: 0.3872 - val_accuracy: 0.8421 - lr: 1.0000e-04
# Epoch 16/250
# 15/15 [==============================] - 0s 31ms/step - loss: 0.2955 - accuracy: 0.8945 - val_loss: 0.3679 - val_accuracy: 0.8596 - lr: 1.0000e-04
# Epoch 17/250
# 15/15 [==============================] - 0s 28ms/step - loss: 0.3054 - accuracy: 0.8791 - val_loss: 0.3501 - val_accuracy: 0.8684 - lr: 1.0000e-04
# Epoch 18/250
# 15/15 [==============================] - 1s 86ms/step - loss: 0.2883 - accuracy: 0.8879 - val_loss: 0.3308 - val_accuracy: 0.8860 - lr: 1.0000e-04
# Epoch 19/250
# 15/15 [==============================] - 1s 58ms/step - loss: 0.2695 - accuracy: 0.8835 - val_loss: 0.3104 - val_accuracy: 0.8947 - lr: 1.0000e-04
# Epoch 20/250
# 15/15 [==============================] - 1s 77ms/step - loss: 0.2583 - accuracy: 0.9033 - val_loss: 0.2915 - val_accuracy: 0.9211 - lr: 1.0000e-04
# Epoch 21/250
# 15/15 [==============================] - 1s 44ms/step - loss: 0.2477 - accuracy: 0.8923 - val_loss: 0.2712 - val_accuracy: 0.9386 - lr: 1.0000e-04
# Epoch 22/250
# 15/15 [==============================] - 1s 46ms/step - loss: 0.2618 - accuracy: 0.9011 - val_loss: 0.2553 - val_accuracy: 0.9386 - lr: 1.0000e-04
# Epoch 23/250
# 15/15 [==============================] - 0s 27ms/step - loss: 0.2301 - accuracy: 0.9121 - val_loss: 0.2410 - val_accuracy: 0.9386 - lr: 1.0000e-04
# Epoch 24/250
# 15/15 [==============================] - 1s 44ms/step - loss: 0.2434 - accuracy: 0.9121 - val_loss: 0.2264 - val_accuracy: 0.9474 - lr: 1.0000e-04
# Epoch 25/250
# 15/15 [==============================] - 0s 27ms/step - loss: 0.2478 - accuracy: 0.9055 - val_loss: 0.2137 - val_accuracy: 0.9386 - lr: 1.0000e-04
# Epoch 26/250
# 15/15 [==============================] - 1s 64ms/step - loss: 0.2208 - accuracy: 0.9209 - val_loss: 0.2020 - val_accuracy: 0.9386 - lr: 1.0000e-04
# Epoch 27/250
# 15/15 [==============================] - 0s 24ms/step - loss: 0.2183 - accuracy: 0.9165 - val_loss: 0.1904 - val_accuracy: 0.9474 - lr: 1.0000e-04
# Epoch 28/250
# 15/15 [==============================] - 0s 21ms/step - loss: 0.2303 - accuracy: 0.8945 - val_loss: 0.1813 - val_accuracy: 0.9474 - lr: 1.0000e-04
# Epoch 29/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.2286 - accuracy: 0.9099 - val_loss: 0.1727 - val_accuracy: 0.9474 - lr: 1.0000e-04
# Epoch 30/250
# 15/15 [==============================] - 1s 39ms/step - loss: 0.2113 - accuracy: 0.9165 - val_loss: 0.1632 - val_accuracy: 0.9561 - lr: 1.0000e-04
# Epoch 31/250
# 15/15 [==============================] - 1s 35ms/step - loss: 0.2028 - accuracy: 0.9297 - val_loss: 0.1557 - val_accuracy: 0.9649 - lr: 1.0000e-04
# Epoch 32/250
# 15/15 [==============================] - 0s 23ms/step - loss: 0.2118 - accuracy: 0.9209 - val_loss: 0.1483 - val_accuracy: 0.9649 - lr: 1.0000e-04
# Epoch 33/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.2115 - accuracy: 0.9187 - val_loss: 0.1436 - val_accuracy: 0.9649 - lr: 1.0000e-04
# Epoch 34/250
# 15/15 [==============================] - 0s 29ms/step - loss: 0.1866 - accuracy: 0.9253 - val_loss: 0.1388 - val_accuracy: 0.9737 - lr: 1.0000e-04
# Epoch 35/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1893 - accuracy: 0.9341 - val_loss: 0.1341 - val_accuracy: 0.9737 - lr: 1.0000e-04
# Epoch 36/250
# 15/15 [==============================] - 0s 21ms/step - loss: 0.1787 - accuracy: 0.9297 - val_loss: 0.1289 - val_accuracy: 0.9737 - lr: 1.0000e-04
# Epoch 37/250
# 15/15 [==============================] - 1s 54ms/step - loss: 0.2066 - accuracy: 0.9121 - val_loss: 0.1240 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 38/250
# 15/15 [==============================] - 0s 29ms/step - loss: 0.1903 - accuracy: 0.9319 - val_loss: 0.1201 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 39/250
# 15/15 [==============================] - 1s 49ms/step - loss: 0.1911 - accuracy: 0.9297 - val_loss: 0.1178 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 40/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1782 - accuracy: 0.9407 - val_loss: 0.1160 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 41/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1953 - accuracy: 0.9253 - val_loss: 0.1134 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 42/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1737 - accuracy: 0.9319 - val_loss: 0.1112 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 43/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1676 - accuracy: 0.9407 - val_loss: 0.1093 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 44/250
# 15/15 [==============================] - 0s 21ms/step - loss: 0.1823 - accuracy: 0.9407 - val_loss: 0.1071 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 45/250
# 15/15 [==============================] - 0s 28ms/step - loss: 0.1770 - accuracy: 0.9297 - val_loss: 0.1052 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 46/250
# 15/15 [==============================] - 1s 40ms/step - loss: 0.1565 - accuracy: 0.9495 - val_loss: 0.1029 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 47/250
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1536 - accuracy: 0.9407 - val_loss: 0.1007 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 48/250
# 15/15 [==============================] - 0s 27ms/step - loss: 0.1604 - accuracy: 0.9429 - val_loss: 0.0992 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 49/250
# 15/15 [==============================] - 1s 38ms/step - loss: 0.1727 - accuracy: 0.9341 - val_loss: 0.0982 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 50/250
# 15/15 [==============================] - 0s 32ms/step - loss: 0.1554 - accuracy: 0.9516 - val_loss: 0.0966 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 51/250
# 15/15 [==============================] - 0s 27ms/step - loss: 0.1747 - accuracy: 0.9297 - val_loss: 0.0948 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 52/250
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1749 - accuracy: 0.9297 - val_loss: 0.0933 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 53/250
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1485 - accuracy: 0.9473 - val_loss: 0.0909 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 54/250
# 15/15 [==============================] - 0s 26ms/step - loss: 0.1263 - accuracy: 0.9582 - val_loss: 0.0895 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 55/250
# 15/15 [==============================] - 0s 31ms/step - loss: 0.1543 - accuracy: 0.9429 - val_loss: 0.0884 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 56/250
# 15/15 [==============================] - 0s 28ms/step - loss: 0.1521 - accuracy: 0.9495 - val_loss: 0.0879 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 57/250
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1260 - accuracy: 0.9495 - val_loss: 0.0872 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 58/250
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1444 - accuracy: 0.9604 - val_loss: 0.0861 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 59/250
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1494 - accuracy: 0.9429 - val_loss: 0.0859 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 60/250
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1559 - accuracy: 0.9407 - val_loss: 0.0859 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 61/250
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1338 - accuracy: 0.9560 - val_loss: 0.0849 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 62/250
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1443 - accuracy: 0.9429 - val_loss: 0.0840 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 63/250
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1663 - accuracy: 0.9429 - val_loss: 0.0835 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 64/250
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1418 - accuracy: 0.9516 - val_loss: 0.0841 - val_accuracy: 0.9825 - lr: 1.0000e-04
# Epoch 65/250
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1196 - accuracy: 0.9560 - val_loss: 0.0844 - val_accuracy: 0.9737 - lr: 1.0000e-04
# Epoch 66/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1534 - accuracy: 0.9473 - val_loss: 0.0838 - val_accuracy: 0.9737 - lr: 1.0000e-04
# Epoch 67/250
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1535 - accuracy: 0.9473 - val_loss: 0.0837 - val_accuracy: 0.9737 - lr: 2.0000e-05
# Epoch 68/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1437 - accuracy: 0.9385 - val_loss: 0.0831 - val_accuracy: 0.9737 - lr: 2.0000e-05
# Epoch 69/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1565 - accuracy: 0.9538 - val_loss: 0.0829 - val_accuracy: 0.9737 - lr: 2.0000e-05
# Epoch 70/250
# 15/15 [==============================] - 0s 21ms/step - loss: 0.1470 - accuracy: 0.9538 - val_loss: 0.0828 - val_accuracy: 0.9737 - lr: 2.0000e-05
# Epoch 71/250
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1407 - accuracy: 0.9429 - val_loss: 0.0826 - val_accuracy: 0.9737 - lr: 2.0000e-05
# Epoch 72/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1274 - accuracy: 0.9582 - val_loss: 0.0824 - val_accuracy: 0.9737 - lr: 2.0000e-05
# Epoch 73/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1565 - accuracy: 0.9451 - val_loss: 0.0821 - val_accuracy: 0.9737 - lr: 2.0000e-05
# Epoch 74/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1396 - accuracy: 0.9451 - val_loss: 0.0818 - val_accuracy: 0.9825 - lr: 2.0000e-05
# Epoch 75/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1121 - accuracy: 0.9626 - val_loss: 0.0816 - val_accuracy: 0.9825 - lr: 2.0000e-05
# Epoch 76/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1460 - accuracy: 0.9451 - val_loss: 0.0813 - val_accuracy: 0.9825 - lr: 2.0000e-05
# Epoch 77/250
# 15/15 [==============================] - 0s 21ms/step - loss: 0.1196 - accuracy: 0.9538 - val_loss: 0.0811 - val_accuracy: 0.9825 - lr: 2.0000e-05
# Epoch 78/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1122 - accuracy: 0.9670 - val_loss: 0.0809 - val_accuracy: 0.9825 - lr: 2.0000e-05
# Epoch 79/250
# 15/15 [==============================] - 0s 21ms/step - loss: 0.1438 - accuracy: 0.9538 - val_loss: 0.0808 - val_accuracy: 0.9825 - lr: 2.0000e-05
# Epoch 80/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1224 - accuracy: 0.9582 - val_loss: 0.0805 - val_accuracy: 0.9825 - lr: 2.0000e-05
# Epoch 81/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1485 - accuracy: 0.9429 - val_loss: 0.0804 - val_accuracy: 0.9825 - lr: 2.0000e-05
# Epoch 82/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1064 - accuracy: 0.9626 - val_loss: 0.0805 - val_accuracy: 0.9825 - lr: 2.0000e-05
# Epoch 83/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1265 - accuracy: 0.9495 - val_loss: 0.0804 - val_accuracy: 0.9825 - lr: 2.0000e-05
# Epoch 84/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1203 - accuracy: 0.9604 - val_loss: 0.0804 - val_accuracy: 0.9825 - lr: 4.0000e-06
# Epoch 85/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1087 - accuracy: 0.9626 - val_loss: 0.0805 - val_accuracy: 0.9825 - lr: 4.0000e-06
# Epoch 86/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1311 - accuracy: 0.9648 - val_loss: 0.0804 - val_accuracy: 0.9825 - lr: 4.0000e-06
# Epoch 87/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1348 - accuracy: 0.9451 - val_loss: 0.0802 - val_accuracy: 0.9825 - lr: 4.0000e-06
# Epoch 88/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1273 - accuracy: 0.9560 - val_loss: 0.0802 - val_accuracy: 0.9825 - lr: 4.0000e-06
# Epoch 89/250
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1222 - accuracy: 0.9604 - val_loss: 0.0803 - val_accuracy: 0.9825 - lr: 4.0000e-06
# Epoch 90/250
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1374 - accuracy: 0.9495 - val_loss: 0.0801 - val_accuracy: 0.9825 - lr: 4.0000e-06
# Epoch 91/250
# 15/15 [==============================] - 0s 22ms/step - loss: 0.1260 - accuracy: 0.9582 - val_loss: 0.0801 - val_accuracy: 0.9825 - lr: 8.0000e-07
# Epoch 92/250
# 15/15 [==============================] - 0s 23ms/step - loss: 0.1095 - accuracy: 0.9648 - val_loss: 0.0800 - val_accuracy: 0.9825 - lr: 8.0000e-07
# Epoch 93/250
# 15/15 [==============================] - 0s 21ms/step - loss: 0.1222 - accuracy: 0.9582 - val_loss: 0.0801 - val_accuracy: 0.9825 - lr: 8.0000e-07
# Epoch 94/250
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1322 - accuracy: 0.9516 - val_loss: 0.0801 - val_accuracy: 0.9825 - lr: 8.0000e-07
# Epoch 95/250
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1294 - accuracy: 0.9495 - val_loss: 0.0801 - val_accuracy: 0.9825 - lr: 1.6000e-07
# Epoch 96/250
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1509 - accuracy: 0.9473 - val_loss: 0.0800 - val_accuracy: 0.9825 - lr: 1.6000e-07
# Epoch 97/250
# 15/15 [==============================] - 0s 34ms/step - loss: 0.1183 - accuracy: 0.9516 - val_loss: 0.0801 - val_accuracy: 0.9825 - lr: 1.6000e-07

# %%
model.save('cancer_patient_classifier_model.h5')

# %% [markdown]
# # Learning Curve

# %% [markdown]
# The learning curve is a plot that shows how the loss and accuracy of a model change during training. It provides insights into how well the model is learning from the training data and how it generalizes to unseen data. The learning curve typically shows the training and validation loss/accuracy on the y-axis and the number of epochs on the x-axis. By analyzing the learning curve, you can identify if the model is overfitting (high training loss, low validation loss) or underfitting (high training and validation loss). It is a useful tool for monitoring and evaluating the performance of machine learning models.

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy      lr
# 0  0.915624  0.512088  0.674154      0.631579  0.0001
# 1  0.738545  0.606593  0.650817      0.771930  0.0001
# 2  0.572367  0.736264  0.625740      0.780702  0.0001
# 3  0.531851  0.760440  0.601251      0.780702  0.0001
# 4  0.472440  0.789011  0.579522      0.763158  0.0001

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Loss Curve

# %% [markdown]
# Loss curve is a graphical representation that shows how the loss of a machine learning model changes over the course of training. Loss refers to the discrepancy between the predicted output of the model and the true or expected output. The loss curve helps in monitoring the progress of model training and assessing the convergence and performance of the model.

# %%
losses[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Accuracy Curve

# %% [markdown]
# An accuracy curve is a graphical representation that depicts how the accuracy of a machine learning model changes as a specific aspect of the model or training process varies. The accuracy curve is typically plotted against the varying parameter or condition to analyze its impact on the model's accuracy

# %%
losses[['accuracy', 'val_accuracy']].plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = model.predict(x_test)
predict_class = y_pred.argmax(axis = 1)
# Out:
# 4/4 [==============================] - 0s 10ms/step

# %%
print(y_test.iloc[44]), print(predict_class[44])
# Out:
# 0
# 0
# (None, None)

# %%
print(y_test.iloc[78]), print(predict_class[78])
# Out:
# 0
# 0
# (None, None)

# %% [markdown]
# # Error Analysis

# %% [markdown]
# Error analysis is a crucial step in the evaluation and improvement of machine learning models. It involves the systematic examination and understanding of the errors made by the model during prediction. The primary goal of error analysis is to identify patterns and sources of mistakes made by the model, which can provide valuable insights into its performance and guide improvements.

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix = confusion_matrix(y_test, predict_class)

# %%
confusion_matrix
# Out:
# array([[71,  0],
#        [43,  0]], dtype=int64)

# %%
plt.figure(figsize = (6, 4))
sns.heatmap(confusion_matrix, 
            annot = True, 
            cmap = 'RdPu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Thanks !
